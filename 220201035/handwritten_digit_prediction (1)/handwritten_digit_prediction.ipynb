# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
import cv2

# %%
# Step 2: Load and Preprocess Dataset
data_dir = '/content/drive/MyDrive/bangla_digits'
digit_folders = [f'digit_{i}' for i in range(10)]
images = []
labels = []

# %%
for digit, folder in enumerate(digit_folders):
    folder_path = os.path.join(data_dir, folder)
    if not os.path.exists(folder_path):
        print(f"Error: Folder {folder_path} not found")
        raise FileNotFoundError(f"Folder {folder_path} not found")

    for i in range(1, 21):  # Images bangla_X_1.png to bangla_X_20.png
        img_name = f'bangla_{digit}_{i}.png'
        img_path = os.path.join(folder_path, img_name)
        if not os.path.exists(img_path):
            print(f"Warning: Image {img_path} not found, skipping")
            continue

        # Load image in grayscale
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Warning: Failed to load {img_path}, skipping")
            continue

        # Resize to 28x28 (like MNIST)
        img = cv2.resize(img, (28, 28))
        # Normalize pixel values to [0, 1]
        img = img.astype('float32') / 255.0
        # Reshape to (28, 28, 1) for CNN input
        img = np.expand_dims(img, axis=-1)

        images.append(img)
        labels.append(digit)

# %%
X = np.array(images)
y = np.array(labels)

# %%
print(f"Loaded {len(X)} images with shape {X.shape}")
print("Label distribution:")
print(pd.Series(y).value_counts())
# Out:
# Loaded 200 images with shape (200, 28, 28, 1)
# Label distribution:
# 0    20
# 1    20
# 2    20
# 3    20
# 4    20
# 5    20
# 6    20
# 7    20
# 8    20
# 9    20
# Name: count, dtype: int64

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.1,
    fill_mode='nearest'
)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold = 1
accuracies = []
classification_reports = []

for train_idx, test_idx in skf.split(X, y):
    print(f"\nFold {fold}")
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    # Split train into train+validation
    X_train, X_val, y_train, y_val = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42, stratify=y_train
    )

    print(f"Train samples: {len(X_train)}, Validation samples: {len(X_val)}, Test samples: {len(X_test)}")
    print("Test label distribution:")
    print(pd.Series(y_test).value_counts())

    # Step 5: Build CNN Model
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(10, activation='softmax')  # 10 classes (digits 0-9)
    ])

    # Compile model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Step 6: Train Model with Data Augmentation
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0001)

    # Fit model with augmentation
    history = model.fit(
        datagen.flow(X_train, y_train, batch_size=32),
        epochs=50,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Step 7: Evaluate Model
    y_pred = np.argmax(model.predict(X_test), axis=1)
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)
    print(f"Fold {fold} Test Accuracy: {accuracy:.4f}")

    # Classification report
    report = classification_report(y_test, y_pred, target_names=[f'০ ({i})' for i in range(10)], output_dict=True)
    classification_reports.append(report)
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=[f'০ ({i})' for i in range(10)]))

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[f'০ ({i})' for i in range(10)], yticklabels=[f'০ ({i})' for i in range(10)])
    plt.title(f'Confusion Matrix - Fold {fold}')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
    plt.close()

    # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig(f'/content/drive/MyDrive/bangla_digits/training_plots_fold_{fold}.png')
    plt.close()

    fold += 1
# Out:
# Fold 1
# Train samples: 144, Validation samples: 16, Test samples: 40
# Test label distribution:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: count, dtype: int64
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.0590 - loss: 2.3649 - val_accuracy: 0.0625 - val_loss: 2.2978 - learning_rate: 0.0010
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.0619 - loss: 2.3213 - val_accuracy: 0.2500 - val_loss: 2.3008 - learning_rate: 0.0010
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.0661 - loss: 2.3114 - val_accuracy: 0.1250 - val_loss: 2.3036 - learning_rate: 0.0010
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.1409 - loss: 2.2962 - val_accuracy: 0.1250 - val_loss: 2.3054 - learning_rate: 0.0010
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.0579 - loss: 2.2994 - val_accuracy: 0.0625 - val_loss: 2.3061 - learning_rate: 2.0000e-04
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.0780 - loss: 2.3033 - val_accuracy: 0.0625 - val_loss: 2.3070 - learning_rate: 2.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Fold 1 Test Accuracy: 0.0250
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        ০ (0)       0.00      0.00      0.00         4
#        ০ (1)       0.00      0.00      0.00         4
#        ০ (2)       0.00      0.00      0.00         4
#        ০ (3)       0.04      0.25      0.07         4
#        ০ (4)       0.00      0.00      0.00         4
#        ০ (5)       0.00      0.00      0.00         4
#        ০ (6)       0.00      0.00      0.00         4
#        ০ (7)       0.00      0.00      0.00         4
#        ০ (8)       0.00      0.00      0.00         4
#        ০ (9)       0.00      0.00      0.00         4
#
#     accuracy                           0.03        40
#    macro avg       0.00      0.03      0.01        40
# weighted avg       0.00      0.03      0.01        40
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.draw()
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Matplotlib currently does not support Bengali natively.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# Fold 2
# Train samples: 144, Validation samples: 16, Test samples: 40
# Test label distribution:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: count, dtype: int64
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.0372 - loss: 2.3486 - val_accuracy: 0.0625 - val_loss: 2.3188 - learning_rate: 0.0010
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.0855 - loss: 2.3146 - val_accuracy: 0.0625 - val_loss: 2.3176 - learning_rate: 0.0010
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0676 - loss: 2.3075 - val_accuracy: 0.0625 - val_loss: 2.3083 - learning_rate: 0.0010
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1015 - loss: 2.3059 - val_accuracy: 0.1875 - val_loss: 2.2963 - learning_rate: 0.0010
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1202 - loss: 2.3002 - val_accuracy: 0.1250 - val_loss: 2.2892 - learning_rate: 0.0010
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1316 - loss: 2.2897 - val_accuracy: 0.2500 - val_loss: 2.2914 - learning_rate: 0.0010
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1294 - loss: 2.2852 - val_accuracy: 0.2500 - val_loss: 2.2889 - learning_rate: 0.0010
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2076 - loss: 2.2641 - val_accuracy: 0.1875 - val_loss: 2.2756 - learning_rate: 0.0010
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.1548 - loss: 2.2498 - val_accuracy: 0.2500 - val_loss: 2.2498 - learning_rate: 0.0010
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1811 - loss: 2.2473 - val_accuracy: 0.1250 - val_loss: 2.2323 - learning_rate: 0.0010
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1907 - loss: 2.2203 - val_accuracy: 0.2500 - val_loss: 2.1910 - learning_rate: 0.0010
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3065 - loss: 2.1461 - val_accuracy: 0.1875 - val_loss: 2.1352 - learning_rate: 0.0010
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2592 - loss: 2.1500 - val_accuracy: 0.1875 - val_loss: 2.0883 - learning_rate: 0.0010
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3230 - loss: 2.1083 - val_accuracy: 0.1875 - val_loss: 2.0123 - learning_rate: 0.0010
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3161 - loss: 1.9709 - val_accuracy: 0.1875 - val_loss: 1.9346 - learning_rate: 0.0010
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3796 - loss: 1.9408 - val_accuracy: 0.3125 - val_loss: 1.8718 - learning_rate: 0.0010
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3992 - loss: 1.8637 - val_accuracy: 0.2500 - val_loss: 1.8565 - learning_rate: 0.0010
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3890 - loss: 1.7904 - val_accuracy: 0.1875 - val_loss: 1.8455 - learning_rate: 0.0010
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3464 - loss: 1.9357 - val_accuracy: 0.2500 - val_loss: 1.7807 - learning_rate: 0.0010
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4175 - loss: 1.7140 - val_accuracy: 0.3125 - val_loss: 1.7685 - learning_rate: 0.0010
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3230 - loss: 1.8383 - val_accuracy: 0.2500 - val_loss: 1.8142 - learning_rate: 0.0010
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4281 - loss: 1.7330 - val_accuracy: 0.1875 - val_loss: 1.8519 - learning_rate: 0.0010
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.4038 - loss: 1.6619 - val_accuracy: 0.2500 - val_loss: 1.8697 - learning_rate: 0.0010
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4364 - loss: 1.6782 - val_accuracy: 0.2500 - val_loss: 1.8447 - learning_rate: 2.0000e-04
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4531 - loss: 1.6481 - val_accuracy: 0.3125 - val_loss: 1.8124 - learning_rate: 2.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Fold 2 Test Accuracy: 0.5000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        ০ (0)       0.50      0.25      0.33         4
#        ০ (1)       0.33      0.50      0.40         4
#        ০ (2)       0.44      1.00      0.62         4
#        ০ (3)       0.00      0.00      0.00         4
#        ০ (4)       1.00      0.25      0.40         4
#        ০ (5)       0.67      0.50      0.57         4
#        ০ (6)       0.50      0.50      0.50         4
#        ০ (7)       0.50      1.00      0.67         4
#        ০ (8)       0.60      0.75      0.67         4
#        ০ (9)       0.50      0.25      0.33         4
#
#     accuracy                           0.50        40
#    macro avg       0.50      0.50      0.45        40
# weighted avg       0.50      0.50      0.45        40
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.draw()
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Matplotlib currently does not support Bengali natively.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# Fold 3
# Train samples: 144, Validation samples: 16, Test samples: 40
# Test label distribution:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: count, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.0720 - loss: 2.3776 - val_accuracy: 0.1250 - val_loss: 2.3100 - learning_rate: 0.0010
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2147 - loss: 2.2534 - val_accuracy: 0.0625 - val_loss: 2.3140 - learning_rate: 0.0010
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1356 - loss: 2.3110 - val_accuracy: 0.0625 - val_loss: 2.3089 - learning_rate: 0.0010
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.0870 - loss: 2.3199 - val_accuracy: 0.1875 - val_loss: 2.2974 - learning_rate: 0.0010
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1378 - loss: 2.2916 - val_accuracy: 0.0625 - val_loss: 2.2896 - learning_rate: 0.0010
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1307 - loss: 2.2826 - val_accuracy: 0.2500 - val_loss: 2.2792 - learning_rate: 0.0010
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1353 - loss: 2.2874 - val_accuracy: 0.1875 - val_loss: 2.2662 - learning_rate: 0.0010
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1040 - loss: 2.2678 - val_accuracy: 0.1875 - val_loss: 2.2620 - learning_rate: 0.0010
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1595 - loss: 2.2809 - val_accuracy: 0.2500 - val_loss: 2.2313 - learning_rate: 0.0010
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1253 - loss: 2.2708 - val_accuracy: 0.2500 - val_loss: 2.2007 - learning_rate: 0.0010
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1815 - loss: 2.2362 - val_accuracy: 0.1875 - val_loss: 2.1829 - learning_rate: 0.0010
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.2021 - loss: 2.2072 - val_accuracy: 0.2500 - val_loss: 2.1248 - learning_rate: 0.0010
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2065 - loss: 2.1665 - val_accuracy: 0.2500 - val_loss: 2.0728 - learning_rate: 0.0010
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2493 - loss: 2.0851 - val_accuracy: 0.3125 - val_loss: 1.9898 - learning_rate: 0.0010
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3051 - loss: 2.0347 - val_accuracy: 0.3125 - val_loss: 1.9593 - learning_rate: 0.0010
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2627 - loss: 2.0121 - val_accuracy: 0.3750 - val_loss: 1.8779 - learning_rate: 0.0010
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2898 - loss: 2.0450 - val_accuracy: 0.2500 - val_loss: 1.8955 - learning_rate: 0.0010
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2321 - loss: 2.0740 - val_accuracy: 0.3750 - val_loss: 1.8862 - learning_rate: 0.0010
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3715 - loss: 1.9331 - val_accuracy: 0.2500 - val_loss: 1.8272 - learning_rate: 0.0010
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3089 - loss: 1.9920 - val_accuracy: 0.2500 - val_loss: 1.7836 - learning_rate: 0.0010
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3041 - loss: 1.9564 - val_accuracy: 0.3125 - val_loss: 1.7665 - learning_rate: 0.0010
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3599 - loss: 1.9487 - val_accuracy: 0.3125 - val_loss: 1.7354 - learning_rate: 0.0010
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3650 - loss: 1.8296 - val_accuracy: 0.2500 - val_loss: 1.7291 - learning_rate: 0.0010
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3742 - loss: 1.7454 - val_accuracy: 0.2500 - val_loss: 1.7086 - learning_rate: 0.0010
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3354 - loss: 1.7840 - val_accuracy: 0.3125 - val_loss: 1.6579 - learning_rate: 0.0010
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3336 - loss: 1.8290 - val_accuracy: 0.2500 - val_loss: 1.6831 - learning_rate: 0.0010
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3961 - loss: 1.8434 - val_accuracy: 0.2500 - val_loss: 1.6457 - learning_rate: 0.0010
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4189 - loss: 1.6593 - val_accuracy: 0.2500 - val_loss: 1.6286 - learning_rate: 0.0010
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4165 - loss: 1.8624 - val_accuracy: 0.2500 - val_loss: 1.6480 - learning_rate: 0.0010
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4215 - loss: 1.6549 - val_accuracy: 0.2500 - val_loss: 1.6685 - learning_rate: 0.0010
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3807 - loss: 1.7857 - val_accuracy: 0.3125 - val_loss: 1.6576 - learning_rate: 0.0010
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4459 - loss: 1.6181 - val_accuracy: 0.3125 - val_loss: 1.6447 - learning_rate: 2.0000e-04
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4082 - loss: 1.6246 - val_accuracy: 0.3125 - val_loss: 1.6221 - learning_rate: 2.0000e-04
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4654 - loss: 1.6748 - val_accuracy: 0.3125 - val_loss: 1.6186 - learning_rate: 2.0000e-04
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4487 - loss: 1.7428 - val_accuracy: 0.3125 - val_loss: 1.6118 - learning_rate: 2.0000e-04
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4148 - loss: 1.7058 - val_accuracy: 0.3125 - val_loss: 1.5724 - learning_rate: 2.0000e-04
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.3812 - loss: 1.7482 - val_accuracy: 0.3125 - val_loss: 1.5603 - learning_rate: 2.0000e-04
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3669 - loss: 1.6685 - val_accuracy: 0.3125 - val_loss: 1.5554 - learning_rate: 2.0000e-04
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4467 - loss: 1.7745 - val_accuracy: 0.3125 - val_loss: 1.5666 - learning_rate: 2.0000e-04
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.4804 - loss: 1.6368 - val_accuracy: 0.3750 - val_loss: 1.5711 - learning_rate: 2.0000e-04
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4076 - loss: 1.7189 - val_accuracy: 0.3750 - val_loss: 1.5640 - learning_rate: 2.0000e-04
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.4951 - loss: 1.5373 - val_accuracy: 0.3750 - val_loss: 1.5574 - learning_rate: 1.0000e-04
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.4738 - loss: 1.6105 - val_accuracy: 0.3750 - val_loss: 1.5517 - learning_rate: 1.0000e-04
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4525 - loss: 1.6542 - val_accuracy: 0.3750 - val_loss: 1.5493 - learning_rate: 1.0000e-04
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4800 - loss: 1.5348 - val_accuracy: 0.3750 - val_loss: 1.5514 - learning_rate: 1.0000e-04
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4248 - loss: 1.7323 - val_accuracy: 0.3750 - val_loss: 1.5563 - learning_rate: 1.0000e-04
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3982 - loss: 1.7660 - val_accuracy: 0.3750 - val_loss: 1.5584 - learning_rate: 1.0000e-04
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5222 - loss: 1.6029 - val_accuracy: 0.3750 - val_loss: 1.5613 - learning_rate: 1.0000e-04
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4015 - loss: 1.6870 - val_accuracy: 0.3125 - val_loss: 1.5573 - learning_rate: 1.0000e-04
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bc606d1e340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bc606d1e340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.draw()
# Fold 3 Test Accuracy: 0.6750
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        ০ (0)       0.50      0.75      0.60         4
#        ০ (1)       0.50      0.25      0.33         4
#        ০ (2)       1.00      1.00      1.00         4
#        ০ (3)       1.00      0.25      0.40         4
#        ০ (4)       0.75      0.75      0.75         4
#        ০ (5)       0.60      0.75      0.67         4
#        ০ (6)       0.50      0.25      0.33         4
#        ০ (7)       1.00      1.00      1.00         4
#        ০ (8)       0.50      1.00      0.67         4
#        ০ (9)       0.75      0.75      0.75         4
#
#     accuracy                           0.68        40
#    macro avg       0.71      0.68      0.65        40
# weighted avg       0.71      0.68      0.65        40
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Matplotlib currently does not support Bengali natively.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# Fold 4
# Train samples: 144, Validation samples: 16, Test samples: 40
# Test label distribution:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: count, dtype: int64
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.1159 - loss: 2.3346 - val_accuracy: 0.0625 - val_loss: 2.3202 - learning_rate: 0.0010
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.0518 - loss: 2.3478 - val_accuracy: 0.0625 - val_loss: 2.3002 - learning_rate: 0.0010
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.0854 - loss: 2.3029 - val_accuracy: 0.1250 - val_loss: 2.2982 - learning_rate: 0.0010
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1419 - loss: 2.2891 - val_accuracy: 0.0625 - val_loss: 2.3083 - learning_rate: 0.0010
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1221 - loss: 2.3000 - val_accuracy: 0.0625 - val_loss: 2.2936 - learning_rate: 0.0010
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1163 - loss: 2.2971 - val_accuracy: 0.1250 - val_loss: 2.2702 - learning_rate: 0.0010
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.1624 - loss: 2.2696 - val_accuracy: 0.4375 - val_loss: 2.2410 - learning_rate: 0.0010
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1909 - loss: 2.2500 - val_accuracy: 0.3125 - val_loss: 2.2009 - learning_rate: 0.0010
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1425 - loss: 2.2574 - val_accuracy: 0.3750 - val_loss: 2.1812 - learning_rate: 0.0010
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2165 - loss: 2.2302 - val_accuracy: 0.4375 - val_loss: 2.1153 - learning_rate: 0.0010
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3086 - loss: 2.1598 - val_accuracy: 0.5000 - val_loss: 2.0415 - learning_rate: 0.0010
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2413 - loss: 2.1551 - val_accuracy: 0.3750 - val_loss: 1.9425 - learning_rate: 0.0010
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2984 - loss: 2.1257 - val_accuracy: 0.3125 - val_loss: 1.8808 - learning_rate: 0.0010
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2517 - loss: 2.0721 - val_accuracy: 0.3125 - val_loss: 1.8235 - learning_rate: 0.0010
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3005 - loss: 2.0133 - val_accuracy: 0.5000 - val_loss: 1.8123 - learning_rate: 0.0010
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4066 - loss: 1.9051 - val_accuracy: 0.5625 - val_loss: 1.6805 - learning_rate: 0.0010
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3552 - loss: 1.9089 - val_accuracy: 0.5000 - val_loss: 1.5997 - learning_rate: 0.0010
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3806 - loss: 1.8436 - val_accuracy: 0.5625 - val_loss: 1.4992 - learning_rate: 0.0010
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3368 - loss: 1.9523 - val_accuracy: 0.4375 - val_loss: 1.5570 - learning_rate: 0.0010
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3992 - loss: 1.7864 - val_accuracy: 0.5000 - val_loss: 1.5796 - learning_rate: 0.0010
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4019 - loss: 1.8231 - val_accuracy: 0.4375 - val_loss: 1.4503 - learning_rate: 0.0010
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.2867 - loss: 1.7889 - val_accuracy: 0.5000 - val_loss: 1.3982 - learning_rate: 0.0010
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4068 - loss: 1.8212 - val_accuracy: 0.5000 - val_loss: 1.4495 - learning_rate: 0.0010
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.3643 - loss: 1.8116 - val_accuracy: 0.5000 - val_loss: 1.5280 - learning_rate: 0.0010
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.3992 - loss: 1.7602 - val_accuracy: 0.5000 - val_loss: 1.5368 - learning_rate: 0.0010
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3163 - loss: 1.8338 - val_accuracy: 0.5000 - val_loss: 1.5064 - learning_rate: 2.0000e-04
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.4107 - loss: 1.7702 - val_accuracy: 0.5000 - val_loss: 1.4584 - learning_rate: 2.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Fold 4 Test Accuracy: 0.4500
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        ০ (0)       0.25      0.50      0.33         4
#        ০ (1)       0.25      0.25      0.25         4
#        ০ (2)       1.00      0.75      0.86         4
#        ০ (3)       0.50      0.25      0.33         4
#        ০ (4)       0.67      0.50      0.57         4
#        ০ (5)       0.00      0.00      0.00         4
#        ০ (6)       0.40      0.50      0.44         4
#        ০ (7)       0.67      0.50      0.57         4
#        ০ (8)       0.44      1.00      0.62         4
#        ০ (9)       0.50      0.25      0.33         4
#
#     accuracy                           0.45        40
#    macro avg       0.47      0.45      0.43        40
# weighted avg       0.47      0.45      0.43        40
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.draw()
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Matplotlib currently does not support Bengali natively.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# Fold 5
# Train samples: 144, Validation samples: 16, Test samples: 40
# Test label distribution:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: count, dtype: int64
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.1297 - loss: 2.3239 - val_accuracy: 0.0625 - val_loss: 2.3200 - learning_rate: 0.0010
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1072 - loss: 2.2951 - val_accuracy: 0.0000e+00 - val_loss: 2.3224 - learning_rate: 0.0010
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1039 - loss: 2.3073 - val_accuracy: 0.0625 - val_loss: 2.3129 - learning_rate: 0.0010
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1700 - loss: 2.2990 - val_accuracy: 0.1875 - val_loss: 2.3086 - learning_rate: 0.0010
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1013 - loss: 2.2933 - val_accuracy: 0.1250 - val_loss: 2.3039 - learning_rate: 0.0010
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1143 - loss: 2.2913 - val_accuracy: 0.0625 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1172 - loss: 2.2851 - val_accuracy: 0.1250 - val_loss: 2.2947 - learning_rate: 0.0010
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1632 - loss: 2.2551 - val_accuracy: 0.1250 - val_loss: 2.2813 - learning_rate: 0.0010
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1114 - loss: 2.2419 - val_accuracy: 0.1875 - val_loss: 2.2560 - learning_rate: 0.0010
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2049 - loss: 2.2140 - val_accuracy: 0.1250 - val_loss: 2.1998 - learning_rate: 0.0010
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1577 - loss: 2.1620 - val_accuracy: 0.1875 - val_loss: 2.1443 - learning_rate: 0.0010
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1738 - loss: 2.1689 - val_accuracy: 0.1875 - val_loss: 2.1287 - learning_rate: 0.0010
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2086 - loss: 2.1228 - val_accuracy: 0.0625 - val_loss: 2.1568 - learning_rate: 0.0010
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.2966 - loss: 2.0414 - val_accuracy: 0.1250 - val_loss: 2.0960 - learning_rate: 0.0010
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2921 - loss: 1.9928 - val_accuracy: 0.2500 - val_loss: 1.9485 - learning_rate: 0.0010
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2407 - loss: 2.0335 - val_accuracy: 0.3750 - val_loss: 1.9610 - learning_rate: 0.0010
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2681 - loss: 1.9949 - val_accuracy: 0.3125 - val_loss: 1.8866 - learning_rate: 0.0010
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2741 - loss: 1.9824 - val_accuracy: 0.4375 - val_loss: 1.7553 - learning_rate: 0.0010
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3138 - loss: 1.8884 - val_accuracy: 0.4375 - val_loss: 1.7920 - learning_rate: 0.0010
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2518 - loss: 2.0396 - val_accuracy: 0.3125 - val_loss: 1.8046 - learning_rate: 0.0010
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3756 - loss: 1.8532 - val_accuracy: 0.5000 - val_loss: 1.7735 - learning_rate: 0.0010
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.4290 - loss: 1.7820 - val_accuracy: 0.5625 - val_loss: 1.7665 - learning_rate: 2.0000e-04
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3623 - loss: 1.8711 - val_accuracy: 0.5000 - val_loss: 1.7520 - learning_rate: 2.0000e-04
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3150 - loss: 1.9072 - val_accuracy: 0.3125 - val_loss: 1.7379 - learning_rate: 2.0000e-04
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5060 - loss: 1.7852 - val_accuracy: 0.3125 - val_loss: 1.7005 - learning_rate: 2.0000e-04
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3630 - loss: 1.7094 - val_accuracy: 0.4375 - val_loss: 1.6764 - learning_rate: 2.0000e-04
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4658 - loss: 1.5996 - val_accuracy: 0.3750 - val_loss: 1.6661 - learning_rate: 2.0000e-04
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.3869 - loss: 1.7953 - val_accuracy: 0.4375 - val_loss: 1.6580 - learning_rate: 2.0000e-04
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.4302 - loss: 1.6920 - val_accuracy: 0.3750 - val_loss: 1.6556 - learning_rate: 2.0000e-04
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5264 - loss: 1.7025 - val_accuracy: 0.3750 - val_loss: 1.6640 - learning_rate: 2.0000e-04
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.3776 - loss: 1.7295 - val_accuracy: 0.3125 - val_loss: 1.6765 - learning_rate: 2.0000e-04
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4312 - loss: 1.6292 - val_accuracy: 0.3125 - val_loss: 1.6761 - learning_rate: 2.0000e-04
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3916 - loss: 1.6726 - val_accuracy: 0.3125 - val_loss: 1.6704 - learning_rate: 1.0000e-04
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4426 - loss: 1.7287 - val_accuracy: 0.3125 - val_loss: 1.6725 - learning_rate: 1.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Fold 5 Test Accuracy: 0.5000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        ০ (0)       0.25      0.25      0.25         4
#        ০ (1)       0.40      0.50      0.44         4
#        ০ (2)       0.50      0.50      0.50         4
#        ০ (3)       0.00      0.00      0.00         4
#        ০ (4)       1.00      0.25      0.40         4
#        ০ (5)       0.00      0.00      0.00         4
#        ০ (6)       0.60      0.75      0.67         4
#        ০ (7)       0.67      1.00      0.80         4
#        ০ (8)       0.80      1.00      0.89         4
#        ০ (9)       0.43      0.75      0.55         4
#
#     accuracy                           0.50        40
#    macro avg       0.46      0.50      0.45        40
# weighted avg       0.46      0.50      0.45        40
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.11/dist-packages/seaborn/utils.py:61: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.draw()
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')
# <ipython-input-10-a867b7bbb172>:67: UserWarning: Matplotlib currently does not support Bengali natively.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/confusion_matrix_fold_{fold}.png')

# %%
print("\nCross-Validation Summary:")
print(f"Mean Accuracy: {np.mean(accuracies):.4f} (+/- {np.std(accuracies):.4f})")

if classification_reports:
    avg_report = {f'০ ({i})': {'precision': 0, 'recall': 0, 'f1-score': 0} for i in range(10)}
    for report in classification_reports:
        for label in avg_report:
            for metric in ['precision', 'recall', 'f1-score']:
                avg_report[label][metric] += report[label][metric] / len(classification_reports)
    print("\nAverage Classification Report:")
    for label in avg_report:
        print(f"{label}:")
        print(f"  Precision: {avg_report[label]['precision']:.4f}")
        print(f"  Recall: {avg_report[label]['recall']:.4f}")
        print(f"  F1-score: {avg_report[label]['f1-score']:.4f}")
# Out:
# Cross-Validation Summary:
# Mean Accuracy: 0.4300 (+/- 0.2164)
#
# Average Classification Report:
# ০ (0):
#   Precision: 0.3000
#   Recall: 0.3500
#   F1-score: 0.3033
# ০ (1):
#   Precision: 0.2967
#   Recall: 0.3000
#   F1-score: 0.2856
# ০ (2):
#   Precision: 0.5889
#   Recall: 0.6500
#   F1-score: 0.5945
# ০ (3):
#   Precision: 0.3080
#   Recall: 0.1500
#   F1-score: 0.1605
# ০ (4):
#   Precision: 0.6833
#   Recall: 0.3500
#   F1-score: 0.4243
# ০ (5):
#   Precision: 0.2533
#   Recall: 0.2500
#   F1-score: 0.2476
# ০ (6):
#   Precision: 0.4000
#   Recall: 0.4000
#   F1-score: 0.3889
# ০ (7):
#   Precision: 0.5667
#   Recall: 0.7000
#   F1-score: 0.6076
# ০ (8):
#   Precision: 0.4689
#   Recall: 0.7500
#   F1-score: 0.5675
# ০ (9):
#   Precision: 0.4357
#   Recall: 0.4000
#   F1-score: 0.3924

# %%
os.makedirs('/content/drive/MyDrive/bangla_digits', exist_ok=True)
try:
    model.save('/content/drive/MyDrive/bangla_digits/bangla_digit_model.keras')
    print("\nModel saved successfully")
except Exception as e:
    print(f"Error saving model: {e}")
    raise
# Out:
# Model saved successfully

# %%
print("\nPredicting on sample images:")
sample_indices = np.random.choice(len(X_test), 5, replace=False)
for idx in sample_indices:
    img = X_test[idx]
    true_label = y_test[idx]
    pred = np.argmax(model.predict(np.expand_dims(img, axis=0)), axis=1)[0]

    plt.figure(figsize=(3, 3))
    plt.imshow(img.squeeze(), cmap='gray')
    plt.title(f'True: ০ ({true_label}), Pred: ০ ({pred})')
    plt.axis('off')
    plt.savefig(f'/content/drive/MyDrive/bangla_digits/sample_pred_{idx}.png')
    plt.close()
    print(f"Sample {idx}: True Label: ০ ({true_label}), Predicted: ০ ({pred})")
# Out:
# Predicting on sample images:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Sample 25: True Label: ০ (6), Predicted: ০ (9)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# <ipython-input-13-8963581d931d>:12: UserWarning: Glyph 2534 (\N{BENGALI DIGIT ZERO}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/sample_pred_{idx}.png')
# <ipython-input-13-8963581d931d>:12: UserWarning: Matplotlib currently does not support Bengali natively.
#   plt.savefig(f'/content/drive/MyDrive/bangla_digits/sample_pred_{idx}.png')
# Sample 15: True Label: ০ (3), Predicted: ০ (0)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Sample 20: True Label: ০ (5), Predicted: ০ (6)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Sample 18: True Label: ০ (4), Predicted: ০ (4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Sample 35: True Label: ০ (8), Predicted: ০ (8)
